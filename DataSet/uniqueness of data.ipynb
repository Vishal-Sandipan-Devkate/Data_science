# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Lets discover the data of AI usage by student

# %%
stu_ai_data = pd.read_csv(r"D:\Programing\Python Programing\pythonProject\Student_Ai_Uasage_Analysis\DataSet\ai_assistant_usage_student_life.csv")

# %%
stu_ai_data.head()
# Out:
#       SessionID   StudentLevel        Discipline SessionDate  \
# 0  SESSION00001  Undergraduate  Computer Science  03/11/2024
# 1  SESSION00002  Undergraduate        Psychology  25/08/2024
# 2  SESSION00003  Undergraduate          Business  12/01/2025
# 3  SESSION00004  Undergraduate  Computer Science  06/05/2025
# 4  SESSION00005  Undergraduate        Psychology  18/03/2025
#
#    SessionLengthMin  TotalPrompts  TaskType  AI_AssistanceLevel  \
# 0             31.20            11  Studying                   2
# 1             13.09             6  Studying                   3
# 2             19.22             5    Coding                   3
# 3              3.70             1    Coding                   3
# 4             28.12             9   Writing                   3
#
#            FinalOutcome  UsedAgain  SatisfactionRating
# 0  Assignment Completed       True                 1.0
# 1  Assignment Completed       True                 2.0
# ...

# %%
stu_ai_data.shape
# Out:
# (10000, 11)

# %%
stu_ai_data.columns
# Out:
# Index(['SessionID', 'StudentLevel', 'Discipline', 'SessionDate',
#        'SessionLengthMin', 'TotalPrompts', 'TaskType', 'AI_AssistanceLevel',
#        'FinalOutcome', 'UsedAgain', 'SatisfactionRating'],
#       dtype='object')

# %%
stu_ai_data.dtypes
# Out:
# SessionID              object
# StudentLevel           object
# Discipline             object
# SessionDate            object
# SessionLengthMin      float64
# TotalPrompts            int64
# TaskType               object
# AI_AssistanceLevel      int64
# FinalOutcome           object
# UsedAgain                bool
# SatisfactionRating    float64
# dtype: object

# %%
stu_ai_data.isna().sum()
# Out:
# SessionID             0
# StudentLevel          0
# Discipline            0
# SessionDate           0
# SessionLengthMin      0
# TotalPrompts          0
# TaskType              0
# AI_AssistanceLevel    0
# FinalOutcome          0
# UsedAgain             0
# SatisfactionRating    0
# dtype: int64

# %%
unique_identity_of_stu_ai_data = stu_ai_data['SessionID'].nunique()

# %%
stu_ai_data['StudentLevel'].value_counts()
# Out:
# StudentLevel
# Undergraduate    5978
# High School      2027
# Graduate         1995
# Name: count, dtype: int64

# %%
stu_ai_data['Discipline'].value_counts()
# Out:
# Discipline
# Biology             1458
# Computer Science    1445
# Engineering         1430
# Math                1422
# Psychology          1418
# History             1417
# Business            1410
# Name: count, dtype: int64

# %%
stu_ai_data['SessionDate'].value_counts()
# Out:
# SessionDate
# 19/01/2025    41
# 21/06/2025    41
# 16/04/2025    41
# 03/04/2025    41
# 15/08/2024    41
#               ..
# 22/12/2024    17
# 02/04/2025    17
# 30/12/2024    16
# 24/09/2024    15
# 28/12/2024    15
# Name: count, Length: 366, dtype: int64

# %%
stu_ai_data['SessionLengthMin'].value_counts()
# Out:
# SessionLengthMin
# 10.57    12
# 13.40    11
# 8.12     10
# 11.02    10
# 10.33     9
#          ..
# 53.57     1
# 21.54     1
# 77.44     1
# 0.53      1
# 42.82     1
# Name: count, Length: 4078, dtype: int64

# %%
stu_ai_data['TotalPrompts'].value_counts()
# Out:
# TotalPrompts
# 1     1588
# 2     1283
# 3     1226
# 4     1110
# 5      842
# 6      798
# 7      593
# 8      494
# 9      424
# 10     327
# 11     270
# 12     213
# 13     163
# 14     126
# 15     116
# 16      93
# 17      69
# 18      52
# 19      42
# 20      36
# 21      27
# 22      25
# 23      18
# 24      12
# 25      12
# 26       9
# 28       8
# 31       4
# 29       4
# 38       3
# 27       3
# 34       2
# 33       2
# 39       2
# 30       2
# 32       1
# 36       1
# Name: count, dtype: int64

# %%
stu_ai_data['TaskType'].value_counts()
# Out:
# TaskType
# Writing          3101
# Studying         2040
# Homework Help    1959
# Coding           1948
# Brainstorming     476
# Research          476
# Name: count, dtype: int64

# %%
stu_ai_data['AI_AssistanceLevel'].value_counts()
# Out:
# AI_AssistanceLevel
# 4    3451
# 3    3361
# 5    1591
# 2    1356
# 1     241
# Name: count, dtype: int64

# %%
stu_ai_data['FinalOutcome'].value_counts()
# Out:
# FinalOutcome
# Assignment Completed    4768
# Idea Drafted            2866
# Confused                1613
# Gave Up                  753
# Name: count, dtype: int64

# %%
stu_ai_data['UsedAgain'].value_counts()
# Out:
# UsedAgain
# True     7064
# False    2936
# Name: count, dtype: int64

# %%
stu_ai_data['SatisfactionRating'].value_counts()
# Out:
# SatisfactionRating
# 5.0    1236
# 1.0     354
# 3.5     311
# 3.8     311
# 3.4     310
# 3.6     303
# 3.1     296
# 3.9     293
# 3.3     289
# 3.2     289
# 3.7     284
# 2.9     278
# 4.1     275
# 4.2     274
# 4.0     272
# 4.5     258
# 2.8     256
# 4.3     252
# 3.0     252
# 2.7     249
# 4.4     235
# 2.6     233
# 4.6     229
# 2.5     226
# 2.4     219
# 2.3     219
# 4.7     215
# 4.8     211
# 2.2     202
# 4.9     188
# 2.1     158
# 2.0     145
# 1.9     141
# 1.8     127
# 1.7     127
# 1.6     105
# 1.4      95
# 1.5      78
# 1.3      77
# 1.2      74
# 1.1      54
# Name: count, dtype: int64
