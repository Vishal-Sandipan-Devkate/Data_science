# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Dataset_Facebook.csv', sep=';')

# %%
d2 = pd.DataFrame(df)
print(d2)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
d2.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
d2.loc[[1,3,4,6]]
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1            139441  Status         2          12             3         10
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
# 6            139441   Photo         3          12             1          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1   0.0                      10460                            19057
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# 6   1.0                      11692                            19479
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 1                    1457                     1361
# 3                    2211                      790
# 4                     671                      410
# ...

# %%
d2.loc[1:10]
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3         10
# 2             139441   Photo         3          12             3          3
# 3             139441   Photo         2          12             2         10
# 4             139441   Photo         2          12             2          3
# 5             139441  Status         2          12             1          9
# 6             139441   Photo         3          12             1          3
# 7             139441   Photo         3          12             7          9
# 8             139441  Status         2          12             7          3
# 9             139441   Photo         3          12             6         10
# 10            139441  Status         2          12             5         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# ...

# %%
d2.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
d2.loc[0:10, ['Post Month', 'Paid', 'comment', 'like', 'share']]
# Out:
#     Post Month  Paid  comment    like  share
# 0           12   0.0        4    79.0   17.0
# 1           12   0.0        5   130.0   29.0
# 2           12   0.0        0    66.0   14.0
# 3           12   1.0       58  1572.0  147.0
# 4           12   0.0       19   325.0   49.0
# 5           12   0.0        1   152.0   33.0
# 6           12   1.0        3   249.0   27.0
# 7           12   1.0        0   325.0   14.0
# 8           12   0.0        0   161.0   31.0
# 9           12   0.0        3   113.0   26.0
# 10          12   0.0        0   233.0   19.0

# %%
d2.iloc[[0,1,4,7],[2,3,5]]
# Out:
#    Category  Post Month  Post Hour
# 0         2          12          3
# 1         2          12         10
# 4         2          12          3
# 7         3          12          9

# %%
d3= d2.loc[0:5, ['Post Month', 'Paid']]
d4= d2.loc[6:8, ['Post Month', 'comment', 'like']]

# %%
merge_df = pd.merge(d3, d4, on='Post Month')
merge_df
# Out:
#     Post Month  Paid  comment   like
# 0           12   0.0        3  249.0
# 1           12   0.0        0  325.0
# 2           12   0.0        0  161.0
# 3           12   0.0        3  249.0
# 4           12   0.0        0  325.0
# 5           12   0.0        0  161.0
# 6           12   0.0        3  249.0
# 7           12   0.0        0  325.0
# 8           12   0.0        0  161.0
# 9           12   1.0        3  249.0
# 10          12   1.0        0  325.0
# 11          12   1.0        0  161.0
# 12          12   0.0        3  249.0
# 13          12   0.0        0  325.0
# 14          12   0.0        0  161.0
# 15          12   0.0        3  249.0
# 16          12   0.0        0  325.0
# 17          12   0.0        0  161.0

# %%
d2.sort_index(axis=1, inplace=True)
d2
# Out:
#      Category  Lifetime Engaged Users  \
# 0           2                     178
# 1           2                    1457
# 2           3                     177
# 3           2                    2211
# 4           2                     671
# ..        ...                     ...
# 495         3                     733
# 496         2                     537
# 497         1                     625
# 498         3                     626
# 499         2                     564
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 0                                                  119
# 1                                                 1108
# 2                                                  132
# 3                                                 1386
# 4                                                  396
# ..                                                 ...
# 495                                                392
# ...

# %%
d2.sort_index(axis=1, ascending=False, inplace=True)
d2
# Out:
#      share    like  comment    Type  Total Interactions  Post Weekday  \
# 0     17.0    79.0        4   Photo                 100             4
# 1     29.0   130.0        5  Status                 164             3
# 2     14.0    66.0        0   Photo                  80             3
# 3    147.0  1572.0       58   Photo                1777             2
# 4     49.0   325.0       19   Photo                 393             2
# ..     ...     ...      ...     ...                 ...           ...
# 495   26.0    53.0        5   Photo                  84             7
# 496   22.0    53.0        0   Photo                  75             5
# 497   18.0    93.0        4   Photo                 115             5
# 498   38.0    91.0        7   Photo                 136             4
# 499   28.0    91.0        0   Photo                 119             4
#
#      Post Month  Post Hour  Paid  Page total likes  \
# 0            12          3   0.0            139441
# ...

# %%
d2.sort_index(axis=0, ascending=True, inplace=True)
d2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
#Transpose
res1 = d2.transpose()
res1
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
res2 = d2.shape
res2
# Out:
# (500, 19)

# %%
d2_stacked = d2.stack()
print(d2_stacked.head(15))
# Out:
# 0  Page total likes                                                       139441
#    Type                                                                    Photo
#    Category                                                                    2
#    Post Month                                                                 12
#    Post Weekday                                                                4
#    Post Hour                                                                   3
#    Paid                                                                      0.0
#    Lifetime Post Total Reach                                                2752
#    Lifetime Post Total Impressions                                          5091
#    Lifetime Engaged Users                                                    178
#    Lifetime Post Consumers                                                   109
#    Lifetime Post Consumptions                                                159
# ...
